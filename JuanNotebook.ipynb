# %% [markdown]
# ### Next comes just a test, will create a table namespace object with python just to test interface

# %%
mydata = [(1,'aa',30),(2,'bb',40),(3,'cc',50)]

myschema = "id INT, name STRING, age INT"

df = spark.createDataFrame(mydata,schema=myschema)

# %%
df.display()

# %% [markdown]
# ## will use as well some databricks utilities to have them on the documentation for learning purposes, DButils / databricks utils

# %% [markdown]
# ### need to check if there is data on the container to check if the connection was successful

# %%
dbutils.fs.ls("abfss://source@datalakekillerd.dfs.core.windows.net/")

# %% [markdown]
# **dbutils.widgets**

# %%
dbutils.widgets.text("p_name", "Juan")

# %%
var = dbutils.widgets.get("p_name")

# %% [markdown]
# # Data reading tests

# %%
df_sales = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
        .load("abfss://source@datalakekillerd.dfs.core.windows.net/")

# %%
df_sales.display()

# %% [markdown]
# # PySpark transformations, not all just a few to showcase

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_sales.withColumn("Item_Type", split(col("Item_Type")," ")).display()

# %%
df_sales.withColumn("flag", lit(var)).display()

# %%
df_sales.withColumn("Item_Visibility", col("Item_Visibility").cast(StringType())).display()
df_sales.withColumn("Item_MRP", col("Item_MRP").cast(StringType())).display()

# %%
spark.conf.set("fs.azure.account.auth.type.datalakekillerd.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.datalakekillerd.dfs.core.windows.net",
               "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.datalakekillerd.dfs.core.windows.net",
               "dc0caff8-ff92-40a2-b1c4-5bde8ba44e36")
spark.conf.set("fs.azure.account.oauth2.client.secret.datalakekillerd.dfs.core.windows.net",
               "_hx8Q_1FM0EGy-WFn8tSJTNIzd-xxN-MBcalwkchg")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.datalakekillerd.dfs.core.windows.net",
               "https://login.microsoftonline.com/227858ad-229e-4a57-af4a-2f25aad7ea94/oauth2/token")
